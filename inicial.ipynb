# %% [markdown]
# # Python Insights - Analisando Dados com Python
#
# ### Case - Cancelamento de Clientes
#
# Você foi contratado por uma empresa com mais de 800 mil clientes para um projeto de Dados. Recentemente a empresa percebeu que da sua base total de clientes, a maioria são clientes inativos, ou seja, que já cancelaram o serviço.
#
# Precisando melhorar seus resultados ela quer conseguir entender os principais motivos desses cancelamentos e quais as ações mais eficientes para reduzir esse número.
#
# Base de dados e arquivos: https://drive.google.com/drive/folders/1uDesZePdkhiraJmiyeZ-w5tfc8XsNYFZ?usp=drive_link

# %%
# Passo a passo do projeto
# 1: importar a base de dados
import pandas as pd

tabela = pd.read_csv("cancelamentos.csv")


# 2: vizualizar a base de dados
tabela = tabela.drop(columns= "CustomerID")
display(tabela)


# colunas inuteis - informaçoes que não te ajudam, te atrapalham
# Out:
#         idade    sexo  tempo_como_cliente  frequencia_uso  \
# 0        30.0  Female                39.0            14.0
# 1        65.0  Female                49.0             1.0
# 2        55.0  Female                14.0             4.0
# 3        58.0    Male                38.0            21.0
# 4        23.0    Male                32.0            20.0
# ...       ...     ...                 ...             ...
# 881661   42.0    Male                54.0            15.0
# 881662   25.0  Female                 8.0            13.0
# 881663   26.0    Male                35.0            27.0
# 881664   28.0    Male                55.0            14.0
# 881665   31.0    Male                48.0            20.0
#
#         ligacoes_callcenter  dias_atraso assinatura duracao_contrato  \
# 0                       5.0         18.0   Standard           Annual
# 1                      10.0          8.0      Basic          Monthly
# ...

# %%
# 3: corrigir as cagadas da base de dados
display(tabela.info())

# valores vazios - excluir linhas vazias  
tabela = tabela.dropna()
display(tabela.info())

# float -> numeros decimais
# object/strings -> textos
# int -> numero inteiro
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881666 entries, 0 to 881665
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   idade                   881664 non-null  float64
#  1   sexo                    881664 non-null  object
#  2   tempo_como_cliente      881663 non-null  float64
#  3   frequencia_uso          881663 non-null  float64
#  4   ligacoes_callcenter     881664 non-null  float64
#  5   dias_atraso             881664 non-null  float64
#  6   assinatura              881661 non-null  object
#  7   duracao_contrato        881663 non-null  object
#  8   total_gasto             881664 non-null  float64
#  9   meses_ultima_interacao  881664 non-null  float64
#  10  cancelou                881664 non-null  float64
# dtypes: float64(8), object(3)
# memory usage: 74.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 881659 entries, 0 to 881665
# ...

# %%
# 4: Analise inicial das causas de cancelamentos

# quantas pessoas cancelaram e não cancelaram 
display(tabela["cancelou"].value_counts())

# em percentual
display(tabela["cancelou"].value_counts(normalize=True))    
# display(tabela["cancelou"].value_counts(normalize=True).map("{:.2%}".format))
# Out:
# cancelou
# 1.0    499993
# 0.0    381666
# Name: count, dtype: int64
# cancelou
# 1.0    0.567105
# 0.0    0.432895
# Name: proportion, dtype: float64

# %%
# 5: Analise das causas de cancelamentos (como  as colunas da base impactam no cancelamento)
# graficos/dashboards
# pip install plotly

import plotly.express as px


# criar grafico 
grafico = px.histogram(tabela, x="duracao_contrato")
# exibir o grafico 
grafico.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 9
#       5 import plotly.express as px
#       8 # criar grafico
# ----> 9 grafico = px.histogram(tabela, x="assinatura")
#      10 # exibir o grafico
#      11 grafico.show()
#
# File c:\Users\Dyogu\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\express\_chart_types.py:480, in histogram(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, pattern_shape_sequence, pattern_shape_map, marginal, opacity, orientation, barmode, barnorm, histnorm, log_x, log_y, range_x, range_y, histfunc, cumulative, nbins, text_auto, title, template, width, height)
#     434 def histogram(
#     435     data_frame=None,
# ...
